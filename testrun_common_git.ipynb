# %% [markdown]
# # Test Run: Common/git

# %% [markdown]
# pythonを用いて, ファイルをgithubからdownloadしたり, githubへuploadする.
#
# 準備:
# 1. pythonファイル
#     1. localにフォルダ「Common」を作成
#     2. 「Common」中にフォルダ「common」を作成
#     3. 「common」中に「git.py」, 「display.py」を入れる
# 2. GitHub設定
#     1. GitHubアカウントを作成
#     2. リポジトリを作成 (リポジトリ名: 「Common」)
#         * 公開する予定がなければ「private」をお勧めします
#     3. github tokenを取得
#         * profil > Settings > Developer settings > Personal access tokens > Tokens (classic) > Generate new token
#         * Select scopes > repoにチェックを入れる
#         * 作成されたtokenをコピペ

# %%
from common import git

# %% [markdown]
# github tokenを設定
#
# <span style="color: yellow;">github tokenは取り扱い注意！</span>

# %%
import common_management as cm
github_token = cm.github_token

# %% [markdown]
# ## upload
#
# codeを実行すると, 「Total files: XX. Proceed with upload? [Y/n]:」と表示されるので, Enterもしくは"y"を押してEnter
#
# * jupyter notebookの場合は, 上方のコマンドパレットに上記メッセージが表示されるので, 同じくEnterもしくは"y"を押してEnter
#
# -> uploadが開始される

# %% [markdown]
# ### upload_github()関数

# %% [markdown]
# | **Parameter** | **Type** | **Default** | **Notes** |
# | :--- | :--- | :--- | :--- |
# | owner | str | <span style="color: yellow;">Required</span> | githubリポジトリのオーナー名 |
# | repo | str | <span style="color: yellow;">Required</span> | githubリポジトリ名 |
# | branch | str | <span style="color: yellow;">Required</span> | ブランチ名. とりあえずは'main'でok.|
# | local_path | str | <span style="color: yellow;">Required</span> | アップロードするローカルのファイルまたはディレクトリパス |
# | remote_path | str | <span style="color: yellow;">Required</span> | GitHub上のアップロード先パス |
# | github_token | str | None | GitHub Personal Access Token |
# | is_dir | bool | False | アップロード対象がディレクトリである場合はTrue. ファイルの場合はFalse |
# | commit_message | str | 'Update via script' | GitHubへのコミットメッセージ |
# | confirm | bool | True | アップロード実行前に確認を求めるかどうか |
# | info | bool | True | 進捗情報などの主要情報を表示するかどうか |
# | subinfo | bool | False | 詳細なサブ情報を表示するかどうか |
# | extensions | list[str] | None | uploadするファイルの拡張子. 何も指定しなければpythonファイルが指定される. 複数指定したい場合は['.py', '.ipynb']などのようにlistで指定.  |

# %% [markdown]
# directoryをdownloadする場合 -> is_dir=True

# %%
git.upload_github(
    owner='k11kik',
    repo='Common',
    branch='main',
    local_path='common',
    remote_path='common',
    is_dir=True,
    github_token=github_token
)
# Out:
# [Upload plan]
# 1. common/old_plot.py -> common/old_plot.py
# 2. common/git.py -> common/git.py
# 3. common/plot.py -> common/plot.py
# 4. common/util.py -> common/util.py
# 5. common/__init__.py -> common/__init__.py
# 6. common/quant.py -> common/quant.py
# 7. common/dispersion.py -> common/dispersion.py
# 8. common/pytplot/plot.py -> common/pytplot/plot.py
# 9. common/pytplot/__init__.py -> common/pytplot/__init__.py
# 10. common/pytplot/_core.py -> common/pytplot/_core.py
# 11. common/pytplot/timeclip.py -> common/pytplot/timeclip.py
# 12. common/pytplot/plot_v1.py -> common/pytplot/plot_v1.py
# 13. common/pytplot/time_double.py -> common/pytplot/time_double.py
# 14. common/orbit/_base.py -> common/orbit/_base.py
# 15. common/orbit/orbit.py -> common/orbit/orbit.py
# 16. common/orbit/_plot_orbit.py -> common/orbit/_plot_orbit.py
# 17. common/orbit/__init__.py -> common/orbit/__init__.py
# 18. common/spec/__init__.py -> common/spec/__init__.py
# 19. common/spec/spec.py -> common/spec/spec.py
# 20. common/spec/_svd.py -> common/spec/_svd.py
# 21. common/spec/_spectrogram.py -> common/spec/_spectrogram.py
# 22. common/distribution/_base.py -> common/distribution/_base.py
# 23. common/distribution/__init__.py -> common/distribution/__init__.py
# 24. common/distribution/_plot.py -> common/distribution/_plot.py
# 25. common/time/convert.py -> common/time/convert.py
# 26. common/time/__init__.py -> common/time/__init__.py
# 27. common/cdf/cdf.py -> common/cdf/cdf.py
# 28. common/cdf/pytplot.py -> common/cdf/pytplot.py
# 29. common/cdf/__init__.py -> common/cdf/__init__.py
# 30. common/cdf/cdfdata.py -> common/cdf/cdfdata.py
# 31. common/cdf/_to_pytplot.py -> common/cdf/_to_pytplot.py
# 32. common/coordinate/_to_mfa.py -> common/coordinate/_to_mfa.py
# 33. common/coordinate/__init__.py -> common/coordinate/__init__.py
# 34. common/coordinate/coordinate.py -> common/coordinate/coordinate.py
# 35. common/gmail/gmail_sender.py -> common/gmail/gmail_sender.py
# 36. common/gmail/send_message.py -> common/gmail/send_message.py
# 37. common/gmail/__init__.py -> common/gmail/__init__.py
# 38. common/base/mathpy.py -> common/base/mathpy.py
# 39. common/base/__init__.py -> common/base/__init__.py
# 40. common/base/colored_logging.py -> common/base/colored_logging.py
# 41. common/base/display.py -> common/base/display.py
# 42. common/base/path.py -> common/base/path.py
# 43. common/data_process/resampling.py -> common/data_process/resampling.py
# 44. common/data_process/__init__.py -> common/data_process/__init__.py
# 45. common/data_process/data_process.py -> common/data_process/data_process.py
# [========================================] 45/45 (100.00%) | Time/Iter: 1.09s | ETA: 0:00:009337m
# 2025-12-09 23:37:44 Upload complete: 45/45

# %% [markdown]
# file単体をdownloadする場合 -> is_dir=False

# %%
git.upload_github(
    owner='k11kik',
    repo='Common',
    branch='main',
    local_path='testrun_common_git.ipynb',
    remote_path='',
    is_dir=False,
    github_token=github_token,
    extensions='.ipynb'
)
# Out:
# [Upload plan]
# 1. testrun_common_git.ipynb -> testrun_common_git.ipynb
# [========================================] 1/1 (100.00%) | Time/Iter: 0.00s | ETA: 0:00:00
# 2025-12-09 23:37:49 Upload complete: 1/1

# %% [markdown]
# ## download

# %% [markdown]
# ### download_github()関数

# %% [markdown]
# | **Parameter** | **Type** | **Default** | **Notes** |
# | :--- | :--- | :--- | :--- |
# | owner | str | <span style="color: yellow;">Required</span> | githubリポジトリのオーナー名 |
# | repo | str | <span style="color: yellow;">Required</span> | githubリポジトリ名 |
# | branch | str | <span style="color: yellow;">Required</span> | ブランチ名. とりあえずは'main'でok.|
# | remote_path | str | <span style="color: yellow;">Required</span> | GitHub上のアップロード先パス |
# | github_token | str | None | GitHub Personal Access Token |
# | is_dir | bool | False | アップロード対象がディレクトリである場合はTrue. ファイルの場合はFalse |
# | local_base_dir | str | '.' | ローカルの保存先ベースディレクトリパス |
# | confirm | bool | True | アップロード実行前に確認を求めるかどうか |
# | info | bool | True | 進捗情報などの主要情報を表示するかどうか |
# | subinfo | bool | False | 詳細なサブ情報を表示するかどうか |
# | extensions | list[str] | None | uploadするファイルの拡張子. 何も指定しなければpythonファイルが指定される. 複数指定したい場合は['.py', '.ipynb']などのようにlistで指定.  |

# %% [markdown]
# directoryをdownloadする場合 -> is_dir=True

# %%
git.download_github(
    owner='k11kik',
    repo='Common',
    branch='main',
    remote_path='common',
    is_dir=True,
    github_token=github_token
)
# Out:
# [Download plan]
# Dir: common
# 1. common/__init__.py -> ./common/__init__.py
# 2. common/base/__init__.py -> ./common/base/__init__.py
# 3. common/base/colored_logging.py -> ./common/base/colored_logging.py
# 4. common/base/display.py -> ./common/base/display.py
# 5. common/base/mathpy.py -> ./common/base/mathpy.py
# 6. common/base/path.py -> ./common/base/path.py
# 7. common/cdf/__init__.py -> ./common/cdf/__init__.py
# 8. common/cdf/_to_pytplot.py -> ./common/cdf/_to_pytplot.py
# 9. common/cdf/cdf.py -> ./common/cdf/cdf.py
# 10. common/cdf/cdfdata.py -> ./common/cdf/cdfdata.py
# 11. common/cdf/pytplot.py -> ./common/cdf/pytplot.py
# 12. common/coordinate/__init__.py -> ./common/coordinate/__init__.py
# 13. common/coordinate/_to_mfa.py -> ./common/coordinate/_to_mfa.py
# 14. common/coordinate/coordinate.py -> ./common/coordinate/coordinate.py
# 15. common/data_process/__init__.py -> ./common/data_process/__init__.py
# 16. common/data_process/data_process.py -> ./common/data_process/data_process.py
# 17. common/data_process/resampling.py -> ./common/data_process/resampling.py
# 18. common/dispersion.py -> ./common/dispersion.py
# 19. common/distribution/__init__.py -> ./common/distribution/__init__.py
# 20. common/distribution/_base.py -> ./common/distribution/_base.py
# 21. common/distribution/_plot.py -> ./common/distribution/_plot.py
# 22. common/git.py -> ./common/git.py
# 23. common/gmail/__init__.py -> ./common/gmail/__init__.py
# 24. common/gmail/gmail_sender.py -> ./common/gmail/gmail_sender.py
# 25. common/gmail/send_message.py -> ./common/gmail/send_message.py
# 26. common/old_plot.py -> ./common/old_plot.py
# 27. common/orbit/__init__.py -> ./common/orbit/__init__.py
# 28. common/orbit/_base.py -> ./common/orbit/_base.py
# 29. common/orbit/_plot_orbit.py -> ./common/orbit/_plot_orbit.py
# 30. common/orbit/orbit.py -> ./common/orbit/orbit.py
# 31. common/plot.py -> ./common/plot.py
# 32. common/pytplot/__init__.py -> ./common/pytplot/__init__.py
# 33. common/pytplot/_core.py -> ./common/pytplot/_core.py
# 34. common/pytplot/plot.py -> ./common/pytplot/plot.py
# 35. common/pytplot/plot_v1.py -> ./common/pytplot/plot_v1.py
# 36. common/pytplot/time_double.py -> ./common/pytplot/time_double.py
# 37. common/pytplot/timeclip.py -> ./common/pytplot/timeclip.py
# 38. common/quant.py -> ./common/quant.py
# 39. common/spec/__init__.py -> ./common/spec/__init__.py
# 40. common/spec/_spectrogram.py -> ./common/spec/_spectrogram.py
# 41. common/spec/_svd.py -> ./common/spec/_svd.py
# 42. common/spec/spec.py -> ./common/spec/spec.py
# 43. common/time/__init__.py -> ./common/time/__init__.py
# 44. common/time/convert.py -> ./common/time/convert.py
# 45. common/util.py -> ./common/util.py
# Download cancelled.

# %% [markdown]
# file単体をdownloadする場合 -> is_dir=False

# %%
git.download_github(
    owner='k11kik',
    repo='Common',
    branch='main',
    remote_path='testrun_common_git.ipynb',
    is_dir=False,
    github_token=github_token,
    extensions='.ipynb'
)
# Out:
# [Download plan]
# File: testrun_common_git.ipynb
# 1. testrun_common_git.ipynb -> ./testrun_common_git.ipynb
# Download cancelled.
